# %%
import seaborn as sns
import matplotlib.pyplot as plt

from utils import load_data

sns.set_style("whitegrid")
sns.set_context("notebook")

plt.rcParams.update({
    'svg.fonttype': 'none',  # Export text as text not curves
    'font.size': 16, 
    "lines.linewidth": 2, 
    "axes.labelsize": 18,
    "axes.titlesize": 22
})

# %%
#parameters
db = "enamine_10k_batch.sqlite"
TITLE = "Enamine10k"

# %%
# Parameters
db = "mcl1_mmpbsa_gb_shuffled.sqlite"
TITLE = "MCL1-MMPBSA"

# %%
OUTPUT_PREFIX = db.split(".")[0]

# %%
data, top_k, source = load_data(f"results/{db}", k_ratio=0.01)
K = len(top_k)
data.head()
# Out:
#    id  experiment_id                                       molecule  \
# 0   1              1  O=C(OCc1cccc2cccnc12)c1[nH]c2c(Br)cccc2c1CCCO
# 1   2              1   C=CC[C@](C)(CC)COC(=O)CCc1c[nH]c2cc(Cl)ccc12
# 2   3              1                  O=C(O)c1[nH]c2ccc(Br)cc2c1CCO
# 3   4              1   O=C(OCc1cccc(F)c1Br)c1[nH]c2c(Br)cccc2c1CCCO
# 4   5              1  O=C(OCc1c(Br)cncc1Br)c1[nH]c2c(Br)cccc2c1CCCO
#
#     affinity  prediction_mean  prediction_std  Iteration  cluster  \
# 0 -41.948575       -41.948575        0.702393          0        0
# 1 -32.127669       -41.948575        2.004909          1        0
# 2 -26.643830       -42.310369        0.046878          2        0
# 3 -41.867471       -41.311815        1.361735          3        0
# 4 -42.256509       -42.008830        0.281149          4        0
#
#   output_file_path  is_validation_result  ...              output_file  \
# 0             None                     0  ...  mcl1_mmpbsa_gb_shuffled
# 1             None                     0  ...  mcl1_mmpbsa_gb_shuffled
# 2             None                     0  ...  mcl1_mmpbsa_gb_shuffled
# 3             None                     0  ...  mcl1_mmpbsa_gb_shuffled
# 4             None                     0  ...  mcl1_mmpbsa_gb_shuffled
#
#    n_clusters simulator bandit_confidence job_id  Embedding Model Surrogate  \
# 0           1      None               1.0      0        MolFormer    Linear
# 1           1      None               1.0      0        MolFormer    Linear
# 2           1      None               1.0      0        MolFormer    Linear
# 3           1      None               1.0      0        MolFormer    Linear
# 4           1      None               1.0      0        MolFormer    Linear
#
#                 Scoring is_top_k  is_top_k_cum
# 0  Expected Improvement    False             0
# 1  Expected Improvement    False             0
# 2  Expected Improvement    False             0
# 3  Expected Improvement    False             0
# 4  Expected Improvement    False             0
#
# [5 rows x 26 columns]

# %%
HUE_ORDER=sorted(data["Surrogate"].unique())

# %%
g = sns.pointplot(
    data,
    y="affinity",
    x="Embedding Model",
    hue="Surrogate",
    hue_order=HUE_ORDER,
    order=sorted(data["Embedding Model"].unique())
)
g.set_ylabel("Average affinity")
g.set_title(TITLE)
plt.savefig(f"figures/avg_affinity_{OUTPUT_PREFIX}.svg", format="svg")

# %%
data.groupby(["Embedding Model", "Surrogate"])["is_top_k"].agg(lambda x: x.sum() / K)
# Out:
# Embedding Model     Surrogate
# ChemBERTa-2         Linear           0.568067
#                     Random Forest    0.428571
# MolFormer           Linear           0.556303
#                     Random Forest    0.489076
# Morgan Fingerprint  Linear           0.482353
#                     Random Forest    0.368067
# Name: is_top_k, dtype: float64

# %%
g = sns.barplot(
    data,
    y="is_top_k",
    x="Embedding Model",
    hue="Surrogate",
    hue_order=HUE_ORDER,
    errorbar=None,
    estimator = lambda x: x.sum() / K,
    order=sorted(data["Embedding Model"].unique()),
    dodge=True
)
g.set_ylabel(f"Percentage of top-{K} found")
g.set_title(TITLE)
plt.savefig(f"figures/top_k_{OUTPUT_PREFIX}.svg", format="svg")

# %%
import matplotlib.pyplot as plt

use_markers = data["Iteration"].max() < 10

g = sns.relplot(
    data,
    y="is_top_k_cum",
    x="Iteration",
    hue="Embedding Model",
    col="Surrogate",
    col_order=["Linear", "Random Forest"],
    errorbar=None,
    kind="line",
    style="Surrogate",
    style_order=["Linear", "Random Forest"],
    markers="o" if use_markers else None,
    markeredgecolor="k",
    hue_order=sorted(data["Embedding Model"].unique())
)


g.set_xlabels("Molecules screened")
g.set_ylabels(f"Number of top-{K} found")
if use_markers:
    labels = [0] + sorted(data["Iteration"].unique() * len(top_k))
    def set_ticks(**kwargs):
        plt.gca().set_xticklabels(labels)

    g.map(set_ticks)
g.figure.subplots_adjust(top=0.85)
g.figure.suptitle(TITLE, fontsize=16)
g.savefig(f"figures/top_k_iter_{OUTPUT_PREFIX}.svg", format="svg")

# %%
from math import floor
import pandas as pd


results = []
for ratio in range(1, 6):
    
    k = int(floor(len(source) * ratio / 100))
    top = source.sort_values(by="target")[:k]

    is_hit = data["molecule"].isin(top["smiles"])
    retrieval_rates = data[is_hit].groupby(["Embedding Model", "Surrogate"]).size() / k
    retrieval_rates = retrieval_rates.rename("Retrieval Rate")
    retrieval_rates = retrieval_rates.reset_index()


    

    retrieval_rates["top-k%"] = ratio
    retrieval_rates["num"] = k
    results.append(retrieval_rates)

retrieval_results = pd.concat(results)
sns.relplot(retrieval_results, x="top-k%", y="Retrieval Rate", hue="Embedding Model", style="Surrogate", hue_order=sorted(data["Embedding Model"].unique()), alpha=0.8)

# %%
data["AE"] = abs(data["affinity"] - data["prediction_mean"])

g = sns.barplot(
    data,
    y="AE",
    x="Embedding Model",
    hue="Surrogate",
    hue_order=HUE_ORDER,
    order=sorted(data["Embedding Model"].unique()),
    dodge=True
)
g.set_ylabel(f"MAE")
g.set_title(TITLE)
# Out:
# Text(0.5, 1.0, 'MCL1-MMPBSA')
