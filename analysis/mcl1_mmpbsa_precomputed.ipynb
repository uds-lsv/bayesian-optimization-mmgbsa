# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [12]</a>'.</span>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from utils import load_data

sns.set_style("whitegrid")
sns.set_context("notebook")

plt.rcParams.update({
    'svg.fonttype': 'none',  # Export text as text not curves
    'font.size': 16, 
    "lines.linewidth": 2, 
    "axes.labelsize": 18,
    "axes.titlesize": 22
})

# %%
#parameters
db = "enamine_10k"
TITLE = "Enamine10k"

# %%
# Parameters
db = "mcl1_mmpbsa_gb_precomputed"
TITLE = "MCL1-MMGBSA"

# %%
db_batch = f"{db}_batch.sqlite"
db = f"{db}_shuffled.sqlite"
print(db, db_batch)
# Out:
# mcl1_mmpbsa_gb_precomputed_shuffled.sqlite mcl1_mmpbsa_gb_precomputed_batch.sqlite

# %%
if db.startswith("enamine_10k"):
    MOLS_PER_ITER = 100
elif db.startswith("enamine_50k"):
    MOLS_PER_ITER = 500
else:
    MOLS_PER_ITER = 600
MOLS_PER_ITER
# Out:
# 600

# %%
OUTPUT_PREFIX = db.split(".")[0]

# %%
data_batch, top_k_batch, source = load_data(f"results/{db_batch}", k_ratio=0.01)
data, top_k, source = load_data(f"results/{db}", k_ratio=0.01)
assert (top_k_batch == top_k).all().all()
K = len(top_k)
data_batch["Surrogate"] = (data_batch["Surrogate"] + " (B)")
data_batch["Iteration"] *= MOLS_PER_ITER
data["Scenario"] = "Sequential"
data_batch["Scenario"] = "Batched"
df = pd.concat([data, data_batch], ignore_index=True)

# %%
HUE_ORDER=sorted(df["Surrogate"].unique())
HUE_ORDER
# Out:
# ['Linear', 'Linear (B)']

# %%
g = sns.pointplot(
    df,
    y="affinity",
    x="Embedding Model",
    hue="Surrogate",
    hue_order=HUE_ORDER,
    order=sorted(df["Embedding Model"].unique()),
    linestyles=["-", "--", "-", "--"],
    palette=["tab:blue", "tab:blue", "tab:orange", "tab:orange"],
    dodge=True
)
g.set_ylabel("Average affinity")
g.set_title(TITLE)
plt.savefig(f"figures/avg_affinity_{OUTPUT_PREFIX}.svg", format="svg")
# Out:
# /tmp/ipykernel_3325167/207230637.py:1: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   g = sns.pointplot(

# %%
tbl = df.groupby(["Scenario", "Embedding Model", "Surrogate"])["is_top_k"].agg(lambda x: x.sum() / K)
tbl.reset_index().sort_values(by="Embedding Model")
# Out:
#      Scenario        Embedding Model   Surrogate  is_top_k
# 0     Batched  precomputed-finetuned  Linear (B)  0.371429
# 2  Sequential  precomputed-finetuned      Linear  0.559664
# 1     Batched    precomputed-untuned  Linear (B)  0.457143
# 3  Sequential    precomputed-untuned      Linear  0.561345

# %%
g = sns.barplot(
    df,
    y="is_top_k",
    x="Embedding Model",
    hue="Surrogate",
    hue_order=HUE_ORDER,
    errorbar=None,
    estimator = lambda x: x.sum() / K,
    order=sorted(df["Embedding Model"].unique()),
    dodge=True,
    palette="Paired", legend="brief"
)
g.set_ylabel(f"Percentage of top-{K} found")
g.set_title(TITLE)
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 0.7))
plt.savefig(f"figures/top_k_{OUTPUT_PREFIX}.svg", format="svg")

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
from utils import ProcessPlotter

df["Surrogate"] = df["Surrogate"].str.removesuffix(" (B)")
p = ProcessPlotter(df, top_k)
p.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       3 df["Surrogate"] = df["Surrogate"].str.removesuffix(" (B)")
#       4 p = ProcessPlotter(df, top_k)
# ----> 5 p.plot()
#
# File /work/CBG/zinc_project/analysis/utils.py:84, in ProcessPlotter.plot(self)
#      82 def plot(self):
#      83     g = sns.FacetGrid(self.data, col="Surrogate", hue="Embedding Model", aspect=1.2, height=5)
# ---> 84     g.map_dataframe(self.plot_lines)
#      86     self.add_legend(g)
#
# File ~/miniforge3/envs/zinc_project/lib/python3.10/site-packages/seaborn/axisgrid.py:825, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     822     kwargs["data"] = data_ijk
#     824     # Draw the plot
# --> 825     self._facet_plot(func, ax, args, kwargs)
#     827 # For axis labels, prefer to use positional args for backcompat
#     828 # but also extract the x/y kwargs and use if no corresponding arg
#     829 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/miniforge3/envs/zinc_project/lib/python3.10/site-packages/seaborn/axisgrid.py:854, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     852     plot_args = []
#     853     plot_kwargs["ax"] = ax
# --> 854 func(*plot_args, **plot_kwargs)
#     856 # Sort out the supporting information
#     857 self._update_legend_data(ax)
#
# File /work/CBG/zinc_project/analysis/utils.py:98, in ProcessPlotter.plot_lines(self, data, color, **kwargs)
#      91 for group, scene in data.groupby("Scenario"):
#      92     y = scene.groupby("Iteration")["is_top_k_cum"].max() / len(self.top_k)
#      94     plt.plot(
#      95         y.index, y,
#      96         data=scene,
#      97         color=color,
# ---> 98         linestyle=self.styles[model],
#      99         marker=self.markers[group] if group == "Batched" else None,
#     100     )
#     102     plt.xlabel("Iteration")
#     103     plt.ylabel(f"% Top-{len(self.top_k)} retrieved")
#
# KeyError: 'precomputed-finetuned'

# %%
from math import floor
import pandas as pd

N_samples = data.groupby("experiment_id").size().unique()
assert len(N_samples) == 1
N_sampled = N_samples.item()

results = []
for ratio in range(1, 6):
    
    k = int(floor(len(source) * ratio / 100))
    top = source.sort_values(by="target")[:k]

    is_hit = df["molecule"].isin(top["smiles"])
    retrieval_rates = df[is_hit].groupby(["Embedding Model", "Surrogate", "Scenario"]).size() / k
    retrieval_rates = retrieval_rates.rename("Retrieval Rate")
    retrieval_rates = retrieval_rates.reset_index()

    retrieval_rates["top-k%"] = ratio
    retrieval_rates["num"] = k
    results.append(retrieval_rates)

retrieval_results = pd.concat(results)
sns.relplot(
    retrieval_results, x="top-k%", y="Retrieval Rate", hue="Embedding Model",
    hue_order=sorted(data["Embedding Model"].unique()),
    style="Scenario", 
    style_order=["Sequential", "Batched"],
    col="Surrogate", col_order=["Linear", "Random Forest"],
    alpha=0.8
    )
